# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
r1 = np.load("v1.npy")
r2 = np.load("v2.npy")
r4 = np.load("v4.npy")

# %%
plt.plot(r1)
plt.plot(r2)
plt.plot(r4)
plt.ylabel("reward")

# %%
import seaborn as sns

# %%
sns.barplot(data=(r1,r2,r4))
